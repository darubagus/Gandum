# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import seaborn as sns
import numpy as np
# %matplotlib inline

url = 'https://raw.githubusercontent.com/darubagus/Gandum/main/Gandum.csv'
df = pd.read_csv(url, names=["id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"])

df
# Out:
#       id  Daerah  SumbuUtama  SumbuKecil  Keunikan  AreaBulatan   Diameter  \
# 0      1    5781  128.288875   58.470846  0.890095         5954  85.793926
# 1      2    4176  109.348294   49.837688  0.890098         4277  72.918093
# 2      3    4555  114.427991   52.151207  0.890105         4706  76.155145
# 3      4    4141  108.701191   49.457349  0.890499         4236  72.611879
# 4      5    5273  122.747869   55.757848  0.890876         5431  81.937733
# ..   ...     ...         ...         ...       ...          ...        ...
# 495  496    5083  120.083450   54.821580  0.889709         5179  80.447975
# 496  497    4432  112.367050   51.294914  0.889726         4550  75.119889
# 497  498    5020  119.873742   54.718545  0.889740         5104  79.947874
# 498  499    4035  107.311728   48.930802  0.889996         4150  71.676506
# 499  500    3379   99.014789   44.631551  0.892647         3491  65.591741
#
#      KadarAir  Keliling   Bulatan    Ransum  Kelas
# ...

# %%
#No 1
d = df.describe() 
# variance
# df.var()
# Kurang modus, variance, range, IQR, skewness, kurtosis

# %%
#No 2
'''
Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot tersebut.
'''
#Boxplot
df.boxplot(column=["Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir", "Keliling", "Bulatan", "Ransum", "Kelas"])

# %%
# Ini kayanya gausah deh shif wkwk
daerah = df["Daerah"]
daerah.hist()
plt.figure() #Buat misahin graphnya
df.boxplot(column=["Daerah"])

# %%
sumbuUtama = df["SumbuUtama"]
sumbuUtama.hist()
plt.figure()
df.boxplot(column=["SumbuUtama"])

# %%
sumbuKecil = df["SumbuKecil"]
sumbuKecil.hist()
plt.figure()
df.boxplot(column=["SumbuKecil"])

# %%
keunikan = df["Keunikan"]
keunikan.hist()
plt.figure()
df.boxplot(column=["Keunikan"])

# %%
areaBulatan = df["AreaBulatan"]
areaBulatan.hist()
plt.figure()
df.boxplot(column=["AreaBulatan"])

# %%
diameter = df["Diameter"]
diameter.hist()
plt.figure()
df.boxplot(column=["Diameter"])

# %%
kadarAir = df["KadarAir"]
kadarAir.hist()
plt.figure()
df.boxplot(column=["KadarAir"])

# %%
keliling = df["Keliling"]
keliling.hist()
plt.figure()
df.boxplot(column=["Keliling"])

# %%
bulatan = df["Bulatan"]
bulatan.hist()
plt.figure()
df.boxplot(column=["Bulatan"])

# %%
ransum = df["Ransum"]
ransum.hist()
plt.figure()
df.boxplot(column=["Ransum"])

# %%
# Ini juga kayanya gausah deh
kelas = df["Kelas"]
kelas.hist()
plt.figure()
df.boxplot(column=["Kelas"])

# %%
#No 3
'''
Menentukan setiap kolom numerik berdistribusi normal atau tidak. Gunakan normality test yang dikaitkan dengan histogram plot.
'''
sumbuUtama = df["SumbuUtama"]
alpha = 0.05
stat, p = stats.normaltest(sumbuUtama)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(sumbuUtama)
# Out:
# alpha = 0.050
# stat = 95.120, p-value = 0.000
# Data is not normally distributed

# %%
sumbuKecil = df["SumbuKecil"]
alpha = 0.05
stat, p = stats.normaltest(sumbuKecil)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(sumbuKecil)
# Out:
# alpha = 0.050
# stat = 3.698, p-value = 0.157
# Data is normally distributed

# %%
keunikan = df["Keunikan"]
alpha = 0.05
stat, p = stats.normaltest(keunikan)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(keunikan)
# Out:
# alpha = 0.050
# stat = 158.617, p-value = 0.000
# Data is not normally distributed

# %%
areaBulatan = df["AreaBulatan"]
alpha = 0.05
stat, p = stats.normaltest(areaBulatan)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(areaBulatan)
# Out:
# alpha = 0.050
# stat = 10.739, p-value = 0.005
# Data is not normally distributed

# %%
diameter = df["Diameter"]
alpha = 0.05
stat, p = stats.normaltest(diameter)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(diameter)
# Out:
# alpha = 0.050
# stat = 7.446, p-value = 0.024
# Data is not normally distributed

# %%
kadarAir = df["KadarAir"]
alpha = 0.05
stat, p = stats.normaltest(kadarAir)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(kadarAir)
# Out:
# alpha = 0.050
# stat = 48.756, p-value = 0.000
# Data is not normally distributed

# %%
keliling = df["Keliling"]
alpha = 0.05
stat, p = stats.normaltest(keliling)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(keliling)
# Out:
# alpha = 0.050
# stat = 67.465, p-value = 0.000
# Data is not normally distributed

# %%
bulatan = df["Bulatan"]
alpha = 0.05
stat, p = stats.normaltest(bulatan)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(bulatan)
# Out:
# alpha = 0.050
# stat = 442.119, p-value = 0.000
# Data is not normally distributed

# %%
ransum = df["Ransum"]
alpha = 0.05
stat, p = stats.normaltest(ransum)
print('alpha = %.3f' %(alpha))
print('stat = %.3f, p-value = %.3f' % (stat, p))
# null hypotesis : x comes from a normal distribution
if (p > alpha):
    print('Data is normally distributed')
else :
    print('Data is not normally distributed')

ax = sns.distplot(ransum)
# Out:
# alpha = 0.050
# stat = 37.060, p-value = 0.000
# Data is not normally distributed

# %%
#No 4
'''
Melakukan test hipotesis 1 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.
a. Nilai rata-rata Daerah di atas 4700?
b. Nilai Rata-rata Sumbu Utama tidak sama dengan 116?
c. Nilai Rata-rata 20 baris pertama kolom Sumbu Kecil bukan 50?
d. Proporsi nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15% ?
e. Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5% ?
'''

# %%
#No 5
'''
Melakukan test hipotesis 2 sampel, dengan menuliskan 6 langkah testing dan menampilkan juga boxplotnya untuk kolom/bagian yang bersesuaian.

a. Data kolom AreaBulatan dibagi 2 sama rata: bagian awal dan bagian akhir kolom.
Benarkah rata-rata kedua bagian tersebut sama?
b. Data kolom Kadar Air dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah
rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.2?
c. Rata-rata 20 baris pertama kolom Bulatan sama dengan 20 baris terakhirnya?
d. Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada,
proporsi nilai yang sama di bagian akhir Ransum?
e. Bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya?
'''

# %%
#No 6
'''
Test korelasi: tentukan apakah setiap kolom non-target berkorelasi dengan kolom target, dengan menggambarkan juga scatter plot nya. Gunakan correlation test.
'''
# Kolom target == kolom ke-12 == Kelas

# %%
'''
Pearson correlation coefficient (-1 ≤ r ≤ 1)
Bila r = 1, maka kedua kolom yang dibandingkan memiliki korelasi positif sempurna, artinya jika nilai x membesar, maka nilai y juga membesar dan vice versa
Bila r > 0, maka kolom x dan y memiliki korelasi positif
Bila r = 0, maka kolom x dan y tidak memiliki korelasi
Bila r < 0, maka kolom x dan y memiliki korelasi negatif
Bila r = -1, maka maka kedua kolom yang dibandingkan memiliki korelasi negatif sempurna, artinya jika nilai x membesar, maka nilai y mengecil dan vice versa.

Klasifikasi Pearson correlation coefficient
Perfect --> r +- 1
High Degree --> +- 0.5 < r < +- 1
Moderate Degree --> +- 0.3 < r < +- 0.49
Low Degree --> r < +- 0.29
No Correlation --> r = 0
'''

# %%
# Kolom Daerah : Kolom Kelas
r = np.corrcoef(df["Daerah"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Daerah"], df["Kelas"])
# Out:
# r = -0.603

# %%
# Kolom SumbuUtama : Kolom Kelas
r = np.corrcoef(df["SumbuUtama"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["SumbuUtama"], df["Kelas"])
# Out:
# r = -0.713

# %%
# Kolom SumbuUtama : Kolom Kelas
r = np.corrcoef(df["SumbuKecil"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["SumbuKecil"], df["Kelas"])
# Out:
# r = -0.153

# %%
# Kolom Keunikan : Kolom Kelas
r = np.corrcoef(df["Keunikan"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Keunikan"], df["Kelas"])
# Out:
# r = -0.730

# %%
# Kolom AreaBulatan : Kolom Kelas
r = np.corrcoef(df["AreaBulatan"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["AreaBulatan"], df["Kelas"])
# Out:
# r = -0.607

# %%
# Kolom Diameter : Kolom Kelas
r = np.corrcoef(df["Diameter"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Diameter"], df["Kelas"])
# Out:
# r = -0.603

# %%
# Kolom KadarAir : Kolom Kelas
r = np.corrcoef(df["KadarAir"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["KadarAir"], df["Kelas"])
# Out:
# r = 0.134

# %%
# Kolom Keliling : Kolom Kelas
r = np.corrcoef(df["Keliling"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Keliling"], df["Kelas"])
# Out:
# r = -0.635

# %%
# Kolom Bulatan : Kolom Kelas
r = np.corrcoef(df["Bulatan"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Bulatan"], df["Kelas"])
# Out:
# r = 0.545

# %%
# Kolom Ransum : Kolom Kelas
r = np.corrcoef(df["Ransum"], df["Kelas"])
print("r = %.3f" %(r[0][1]))
sns.regplot(df["Ransum"], df["Kelas"])
# Out:
# r = -0.840
